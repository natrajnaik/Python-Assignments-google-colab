# %%
import pandas as pd

# %% [markdown]
# **Census_2011_using python

# %%
df=pd.read_csv("/content/census_2011.csv")

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Unnamed: 0', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)>

# %%
df.shape
# Out:
# (640, 118)

# %%
df.head()
# Out:
#    Unnamed: 0         State name District name  Population    Male  Female  \
# 0           1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1           2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2           3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3           4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4           5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, Unnamed: 0 to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, Unnamed: 0 to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
#for i,elem in enumerate(df.columns.tolist()):
  print(i,elem)
# Out:
#   File "<ipython-input-64-5447384e82ec>", line 2
#     print(i,elem)
#     ^
# IndentationError: unexpected indent

# %%
cols=['District name','Literate','Households','Housholds_with_Electric_Lighting','Households_with_Telephone_Mobile_Phone']

# %%
k=df[cols]
k
# Out:
#                  District name  Literate  Households  \
# 0                      Kupwara    439654      181664
# 1                       Badgam    335649      187839
# 2                  Leh(Ladakh)     93770       54394
# 3                       Kargil     86236       48144
# 4                        Punch    261724      147408
# ..                         ...       ...         ...
# 635                       Mahe     36470       12110
# 636                   Karaikal    154916       69333
# 637                   Nicobars     25332       15958
# 638  North  AND Middle Andaman     78683       40185
# 639              South Andaman    190266       85532
#
#      Housholds_with_Electric_Lighting  Households_with_Telephone_Mobile_Phone
# 0                               83071                                   56495
# 1                               90190                                   72197
# 2                               17250                                   13836
# ...

# %%
i=k[k['District name']=='Kurnool']
i
# Out:
#     District name  Literate  Households  Housholds_with_Electric_Lighting  \
# 551       Kurnool   2127161     1090835                            816721
#
#      Households_with_Telephone_Mobile_Phone
# 551                                  572406

# %%
i['%Housholds_with_Electric_Lighting']=(i.Housholds_with_Electric_Lighting/i.Households)*100
i
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     District name  Literate  Households  Housholds_with_Electric_Lighting  \
# 551       Kurnool   2127161     1090835                            816721
#
#      Households_with_Telephone_Mobile_Phone  %Housholds_with_Electric_Lighting
# 551                                  572406                          74.871177

# %%
i['%Households_with_Telephone_Mobile_Phone']=(i.Households_with_Telephone_Mobile_Phone/i.Households)*100
i
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     District name  Literate  Households  Housholds_with_Electric_Lighting  \
# 551       Kurnool   2127161     1090835                            816721
#
#      Households_with_Telephone_Mobile_Phone  \
# 551                                  572406
#
#      %Housholds_with_Electric_Lighting  \
# 551                          74.871177
#
#      %Households_with_Telephone_Mobile_Phone
# 551                                52.474114

# %%
summary=i.iloc[:,[0,1,5,6]]
summary
# Out:
#     District name  Literate  %Housholds_with_Electric_Lighting  \
# 551       Kurnool   2127161                          74.871177
#
#      %Households_with_Telephone_Mobile_Phone
# 551                                52.474114

# %%
summary.to_csv("summary_census_2011.csv")
