# %%
# Write a Python program named oops.py to create a Vehicle class with max_speed, current_speedand mileage as attributes/properties.
# Create a Vehicle class without any variables and methods.
# Define a method on class Vehicle which increases the speed by 10 as long as current_speed is lesser than max_speed
# Define a __init__ method which creates new instance of class Vehicle and takes into input color, model

class Vehicle:
  color = "red" # class attr 
  def __init__(self, name, max_speed, current_speed, mileage):
    self.name = name
    self.max_speed = max_speed
    self.current_speed = current_speed
    self.mileage = mileage
    #self.color="green"


  def brake(self):
        if self.current_speed < self.max_speed:
            self.current_speed += 10
        


v = Vehicle("honda", 120, 50,40)

v.color = "violet"
print(v.color)
v.model = "audi"
print(v.model)

# Create a child class Bus that will inherit all of the variables and methods of the Vehicle class

class Bus(Vehicle):
  def __init__(self,n, s, m):
    Vehicle.__init__(self,n, s, m) 


b = Bus('irizar', 180, 10)
