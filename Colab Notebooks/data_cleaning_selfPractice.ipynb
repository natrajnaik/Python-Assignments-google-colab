# %%
path1="/content/drive/MyDrive/sales_dataset/Sales_April_2019.csv"
path2="/content/drive/MyDrive/sales_dataset/Sales_August_2019.csv"
path3="/content/drive/MyDrive/sales_dataset/Sales_December_2019.csv"
path4="/content/drive/MyDrive/sales_dataset/Sales_February_2019.csv"
path5="/content/drive/MyDrive/sales_dataset/Sales_January_2019.csv"
path6="/content/drive/MyDrive/sales_dataset/Sales_July_2019.csv"
path7="/content/drive/MyDrive/sales_dataset/Sales_June_2019.csv"
path8="/content/drive/MyDrive/sales_dataset/Sales_March_2019.csv"
path9="/content/drive/MyDrive/sales_dataset/Sales_May_2019.csv"
path10="/content/drive/MyDrive/sales_dataset/Sales_November_2019.csv"
path11="/content/drive/MyDrive/sales_dataset/Sales_October_2019.csv"
path12="/content/drive/MyDrive/sales_dataset/Sales_September_2019.csv"

# %%
import pandas as pd

# %%
df1=pd.read_csv(path1)
df2=pd.read_csv(path2)
df3=pd.read_csv(path3)
df4=pd.read_csv(path4)
df5=pd.read_csv(path5)
df6=pd.read_csv(path6)
df7=pd.read_csv(path7)
df8=pd.read_csv(path8)
df9=pd.read_csv(path9)
df10=pd.read_csv(path10)
df11=pd.read_csv(path11)
df12=pd.read_csv(path12)

# %%
df1.shape
# Out:
# (18383, 6)

# %%
df1.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df2.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
# 4   236674       AA Batteries (4-pack)                2       3.84
#
#        Order Date                      Purchase Address
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001

# %%
help(pd.concat)
# Out:
# Help on function concat in module pandas.core.reshape.concat:
#
# concat(objs: 'Iterable[NDFrame] | Mapping[Hashable, NDFrame]', axis=0, join='outer', ignore_index: 'bool' = False, keys=None, levels=None, names=None, verify_integrity: 'bool' = False, sort: 'bool' = False, copy: 'bool' = True) -> 'FrameOrSeriesUnion'
#     Concatenate pandas objects along a particular axis with optional set logic
#     along the other axes.
#
#     Can also add a layer of hierarchical indexing on the concatenation axis,
#     which may be useful if the labels are the same (or overlapping) on
#     the passed axis number.
#
#     Parameters
#     ----------
#     objs : a sequence or mapping of Series or DataFrame objects
#         If a mapping is passed, the sorted keys will be used as the `keys`
#         argument, unless it is passed, in which case the values will be
#         selected (see below). Any None objects will be dropped silently unless
# ...

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12],axis=0)

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.shape
# Out:
# (186850, 6)

# %%
#step1... Checking nulls
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df[df.isnull()]
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 0          NaN     NaN              NaN        NaN        NaN              NaN
# 1          NaN     NaN              NaN        NaN        NaN              NaN
# 2          NaN     NaN              NaN        NaN        NaN              NaN
# 3          NaN     NaN              NaN        NaN        NaN              NaN
# 4          NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 11681      NaN     NaN              NaN        NaN        NaN              NaN
# 11682      NaN     NaN              NaN        NaN        NaN              NaN
# 11683      NaN     NaN              NaN        NaN        NaN              NaN
# 11684      NaN     NaN              NaN        NaN        NaN              NaN
# 11685      NaN     NaN              NaN        NaN        NaN              NaN
#
# ...

# %%
df.dropna(axis=0)
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
df.shape
# Out:
# (186850, 6)

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (186305, 6)

# %%
# 2nd step.. dropping duplicates
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (185687, 6)

# %%
#step3.. Checking for wrong datatype
df.info()
# Since all the Dtype is present as object, we need to change into appropriate datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185687 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185687 non-null  object
#  1   Product           185687 non-null  object
#  2   Quantity Ordered  185687 non-null  object
#  3   Price Each        185687 non-null  object
#  4   Order Date        185687 non-null  object
#  5   Purchase Address  185687 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
# We are interested in changing order id into integer from object
# let us change that using a simple expression
import numpy as np
#  df["Order ID"]=df["Order ID"].astype(np.int64)
df["Order ID"]=df["Order ID"].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-1ebcf642e491> in <module>()
#       3 import numpy as np
#       4 #  df["Order ID"]=df["Order ID"].astype(np.int64)
# ----> 5 df["Order ID"]=df["Order ID"].astype(np.int64)
#       6
#       7
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
# The error says there is an order ID present in place of integer value so we cannot change all the valeus into integer
# we need to deleter that particular entity from the column and then it would be possible to convert 

# Lets see if we have that order Id present in the column 
df[df["Order ID"]=='Order ID']
# Out:
#      Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#      Purchase Address
# 519  Purchase Address

# %%
# We can see it clearly that the 519th row contains all strings rather than integers. Need to be changed 
# Let's find out the other values except this 519th row and save that into a new data frame
df=df[df["Order ID"]!='Order ID']
# We can reduce datafame data by one row see below... we got 185686 earlier it was 1..87

# %%
df.shape
# Out:
# (185686, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
# we still din't convert the object into integer for order id column. We have to apply inplace=True
#Lets do that!
df["Order ID"]=df["Order ID"].astype(np.int64)

# %%
df.info()
# After this expression you could have chagned onject dtype to int64 dtype successfully for reference you can run it and see it below.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int64
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 9.9+ MB

# %%
# Similarly we can change other columns datatype into the desired dtype 
df["Quantity Ordered"]=df["Quantity Ordered"].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int64
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 9.9+ MB

# %%
# Similarly we can change other columns datatype into the desired dtype 
df["Price Each"]=df["Price Each"].astype(np.float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int64
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.9+ MB

# %%
# Now will see how can order date be chnaged from obejct into datetime
# df["Order Date"]=pd.to_datetime(df["Order Date"])
df["Order Date"]=df["Order Date"].astype(np.datetime64)  # Both can work

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int64
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 9.9+ MB

# %%
# Now our data is ready for visualization or manupulation
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
df.reset_index()
# Out:
#         index  Order ID                     Product  Quantity Ordered  \
# 0           0    176558        USB-C Charging Cable                 2
# 1           2    176559  Bose SoundSport Headphones                 1
# 2           3    176560                Google Phone                 1
# 3           4    176560            Wired Headphones                 1
# 4           5    176561            Wired Headphones                 1
# ...       ...       ...                         ...               ...
# 185681  11681    259353      AAA Batteries (4-pack)                 3
# 185682  11682    259354                      iPhone                 1
# 185683  11683    259355                      iPhone                 1
# 185684  11684    259356      34in Ultrawide Monitor                 1
# 185685  11685    259357        USB-C Charging Cable                 1
#
#         Price Each          Order Date  \
# 0            11.95 2019-04-19 08:46:00
# 1            99.99 2019-04-07 22:30:00
# ...

# %%
# df['Order ID'].nunique()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 11685
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int64
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  datetime64[ns]
#  5   Purchase Address  185686 non-null  object
#  6   Order Amount      185686 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 11.3+ MB

# %%
# Lets confirm whether our data is perfectly fine without nulls, duplicates and wrong datatypes

df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Order ID            False
# Product             False
# Quantity Ordered    False
# Price Each          False
# Order Date          False
# Purchase Address    False
# dtype: bool

# %%
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
#We can also create a calculated field to have mathematical calculations 

df["Order Amount"]=df["Quantity Ordered"]*df["Price Each"]

# %%
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Order Amount
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001         23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215         99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001        600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001         11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001         11.99

# %%
# You can save your entire work into your drive or at any location that you want to have it

df.to_csv("/content/drive/MyDrive/Data_Cleaning_salesDate.csv")

# %%
#Now, I would like to analise group by opertion on given DataFrame
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Order Amount'],
#       dtype='object')

# %%
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Order Amount
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001         23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215         99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001        600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001         11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001         11.99

# %%
df.groupby(['Product']).sum() # sum() function returns sum of the  values of each column. But I'm interested in finding the sum of values of a particular column
# Out:
#                               Order ID  Quantity Ordered  Price Each  \
# Product
# 20in Monitor                 950247721              4126   450739.02
# 27in 4K Gaming Monitor      1441314778              6239  2427687.75
# 27in FHD Monitor            1722024291              7541  1124625.02
# 34in Ultrawide Monitor      1417418331              6192  2346058.26
# AA Batteries (4-pack)       4739758630             27615    78942.72
# AAA Batteries (4-pack)      4758103011             30986    61629.88
# Apple Airpods Headphones    3573531925             15637  2328750.00
# Bose SoundSport Headphones  3065241918             13430  1329667.02
# Flatscreen TV               1109428389              4813  1438200.00
# Google Phone                1261584746              5529  3313200.00
# LG Dryer                     146556268               646   387600.00
# LG Washing Machine           150718688               666   399600.00
# ...

# %%
df.groupby(['Product','Order Amount']).sum('Order Amount')
# Out:
#                                            Order ID  Quantity Ordered  \
# Product                    Order Amount
# 20in Monitor               109.99         944064388              4070
#                            219.98           6183333                56
# 27in 4K Gaming Monitor     389.99        1438117524              6211
#                            779.98           3197254                28
# 27in FHD Monitor           149.99        1711934633              7455
#                            299.98          10089658                86
# 34in Ultrawide Monitor     379.99        1413349415              6156
#                            759.98           4068916                36
# AA Batteries (4-pack)      3.84          3533663684             15315
#                            7.68           890559602              7746
#                            11.52          237366744              3099
#                            15.36           57640651              1000
# ...

# %%
df[['Product','Order Amount']].groupby('Product').sum() # Right approach for group by @ certain column
# Out:
#                             Order Amount
# Product
# 20in Monitor                   453818.74
# 27in 4K Gaming Monitor        2433147.61
# 27in FHD Monitor              1131074.59
# 34in Ultrawide Monitor        2352898.08
# AA Batteries (4-pack)          106041.60
# AAA Batteries (4-pack)          92648.14
# Apple Airpods Headphones      2345550.00
# Bose SoundSport Headphones    1342865.70
# Flatscreen TV                 1443900.00
# Google Phone                  3317400.00
# LG Dryer                       387600.00
# LG Washing Machine             399600.00
# Lightning Charging Cable       346376.55
# Macbook Pro Laptop            8032500.00
# ThinkPad Laptop               4127958.72
# USB-C Charging Cable           285975.45
# Vareebadd Phone                827200.00
# Wired Headphones               246082.76
# iPhone                        4792900.00

# %%
df[['Product','Order Amount']].groupby('Product',as_index=False).sum()
# Out:
#                        Product  Order Amount
# 0                 20in Monitor     453818.74
# 1       27in 4K Gaming Monitor    2433147.61
# 2             27in FHD Monitor    1131074.59
# 3       34in Ultrawide Monitor    2352898.08
# 4        AA Batteries (4-pack)     106041.60
# 5       AAA Batteries (4-pack)      92648.14
# 6     Apple Airpods Headphones    2345550.00
# 7   Bose SoundSport Headphones    1342865.70
# 8                Flatscreen TV    1443900.00
# 9                 Google Phone    3317400.00
# 10                    LG Dryer     387600.00
# 11          LG Washing Machine     399600.00
# 12    Lightning Charging Cable     346376.55
# 13          Macbook Pro Laptop    8032500.00
# 14             ThinkPad Laptop    4127958.72
# 15        USB-C Charging Cable     285975.45
# 16             Vareebadd Phone     827200.00
# 17            Wired Headphones     246082.76
# 18                      iPhone    4792900.00

# %%
df.groupby('Product').agg(['count','sum','mean'])
# Out:
#                            Order ID                             \
#                               count         sum           mean
# Product
# 20in Monitor                   4098   950247721  231880.849439
# 27in 4K Gaming Monitor         6225  1441314778  231536.510522
# 27in FHD Monitor               7498  1722024291  229664.482662
# 34in Ultrawide Monitor         6174  1417418331  229578.608844
# AA Batteries (4-pack)         20558  4739758630  230555.434867
# AAA Batteries (4-pack)        20612  4758103011  230841.403600
# Apple Airpods Headphones      15525  3573531925  230179.190016
# Bose SoundSport Headphones    13298  3065241918  230503.979395
# Flatscreen TV                  4794  1109428389  231420.189612
# Google Phone                   5522  1261584746  228465.183991
# LG Dryer                        646   146556268  226867.287926
# LG Washing Machine              666   150718688  226304.336336
# Lightning Charging Cable      21610  4982889323  230582.569320
# ...

# %%
df.groupby('Product',as_index=False).agg({'Order ID':'count',
                           'Quantity Ordered':['mean','sum'],
                           'Order Amount':'sum'})
# Out:
#                        Product Order ID Quantity Ordered        Order Amount
#                                   count             mean    sum          sum
# 0                 20in Monitor     4098         1.006833   4126    453818.74
# 1       27in 4K Gaming Monitor     6225         1.002249   6239   2433147.61
# 2             27in FHD Monitor     7498         1.005735   7541   1131074.59
# 3       34in Ultrawide Monitor     6174         1.002915   6192   2352898.08
# 4        AA Batteries (4-pack)    20558         1.343273  27615    106041.60
# 5       AAA Batteries (4-pack)    20612         1.503299  30986     92648.14
# 6     Apple Airpods Headphones    15525         1.007214  15637   2345550.00
# 7   Bose SoundSport Headphones    13298         1.009926  13430   1342865.70
# 8                Flatscreen TV     4794         1.003963   4813   1443900.00
# 9                 Google Phone     5522         1.001268   5529   3317400.00
# ...
