# %%
import csv

# %%
with open("/content/sales.csv",'r') as f:
  reader=csv.reader(f)
  col=next(iter(f))
  rows=[]
  for row in reader:
    rows.append(row)

# %%
for i in rows:
  print(sum((i[10]))
  # print(i[4],sum(float(i[9])),sum(float(i[10])),sum(float(i[12])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b127c812daab> in <module>()
#       1 for i in rows:
# ----> 2   print(sum(i[10]))
#       3   # print(i[4],sum(float(i[9])),sum(float(i[10])),sum(float(i[12])))
#       4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Make a 4*3*2 matrix (NumPy array) containing linearly spaced integers between 100 and 1000.
import numpy as np
