# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(5,5),index=['a','b','c','d','e'],columns=['p','q','r','s','t'])

# %%
df
# Out:
#           p         q         r         s         t
# a -1.276265 -0.441164  1.088538  0.055988 -0.812554
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269
# d -1.273295  0.558726 -0.784153  1.434853  0.587968
# e  1.001514  0.213916  0.417707  0.180338 -0.784085

# %%
df['p']
# Out:
# a   -1.276265
# b   -0.207470
# c    1.046727
# d   -1.273295
# e    1.001514
# Name: p, dtype: float64

# %%
df[['p','s']]
# Out:
#           p         s
# a -1.276265  0.055988
# b -0.207470 -0.392833
# c  1.046727 -0.272427
# d -1.273295  1.434853
# e  1.001514  0.180338

# %%
df.loc['d']
# Out:
# p   -1.273295
# q    0.558726
# r   -0.784153
# s    1.434853
# t    0.587968
# Name: d, dtype: float64

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[0]
# Out:
# p   -1.276265
# q   -0.441164
# r    1.088538
# s    0.055988
# t   -0.812554
# Name: a, dtype: float64

# %%
df.iloc[1] #grabbing the first row, i can either grab it by loc or iloc
# iloc going to ask the indix ( 0,1,2,3,4 etc...)
# Out:
# p   -0.207470
# q    0.464722
# r   -0.704728
# s   -0.392833
# t    1.024017
# Name: b, dtype: float64

# %%
df.loc[['a','b'],['p','q']]
# I can get 2*2 elements from this dataframe
# Out:
#           p         q
# a -1.276265 -0.441164
# b -0.207470  0.464722

# %%
df.loc[['b','d','e'],['q','s']]
# Out:
#           q         s
# b  0.464722 -0.392833
# d  0.558726  1.434853
# e  0.213916  0.180338

# %%
df.iloc[0:2,0:2]
# Out:
#           p         q
# a -1.276265 -0.441164
# b -0.207470  0.464722

# %%
df.iloc[0:4,0:4]
# Out:
#           p         q         r         s
# a -1.276265 -0.441164  1.088538  0.055988
# b -0.207470  0.464722 -0.704728 -0.392833
# c  1.046727  0.369640 -0.859729 -0.272427
# d -1.273295  0.558726 -0.784153  1.434853

# %%
df>0
# Out:
#        p      q      r      s      t
# a  False  False   True   True  False
# b  False   True  False  False   True
# c   True   True  False  False  False
# d  False   True  False   True   True
# e   True   True   True   True  False

# %%
df[df>0]
# Out:
#           p         q         r         s         t
# a       NaN       NaN  1.088538  0.055988       NaN
# b       NaN  0.464722       NaN       NaN  1.024017
# c  1.046727  0.369640       NaN       NaN       NaN
# d       NaN  0.558726       NaN  1.434853  0.587968
# e  1.001514  0.213916  0.417707  0.180338       NaN

# %%
df[df==0]
# Out:
#     p   q   r   s   t
# a NaN NaN NaN NaN NaN
# b NaN NaN NaN NaN NaN
# c NaN NaN NaN NaN NaN
# d NaN NaN NaN NaN NaN
# e NaN NaN NaN NaN NaN

# %%
np.random.rand(5,1)
# Out:
# array([[0.50409069],
#        [0.25954741],
#        [0.46510442],
#        [0.8553662 ],
#        [0.43573491]])

# %%
df['u']=np.random.randn(5,1)

# %%
df
# Out:
#           p         q         r         s         t         u
# a -1.276265 -0.441164  1.088538  0.055988 -0.812554 -1.394389
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017 -1.281944
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269  1.184987
# d -1.273295  0.558726 -0.784153  1.434853  0.587968 -0.226635
# e  1.001514  0.213916  0.417707  0.180338 -0.784085 -1.670345

# %%
df.drop('a')
# Out:
#           p         q         r         s         t         u
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017 -1.281944
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269  1.184987
# d -1.273295  0.558726 -0.784153  1.434853  0.587968 -0.226635
# e  1.001514  0.213916  0.417707  0.180338 -0.784085 -1.670345

# %%
df.drop('u',axis=1)
# Out:
#           p         q         r         s         t
# a -1.276265 -0.441164  1.088538  0.055988 -0.812554
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269
# d -1.273295  0.558726 -0.784153  1.434853  0.587968
# e  1.001514  0.213916  0.417707  0.180338 -0.784085

# %%
df
# Out:
#           p         q         r         s         t         u
# a -1.276265 -0.441164  1.088538  0.055988 -0.812554 -1.394389
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017 -1.281944
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269  1.184987
# d -1.273295  0.558726 -0.784153  1.434853  0.587968 -0.226635
# e  1.001514  0.213916  0.417707  0.180338 -0.784085 -1.670345

# %%
# we have dropped the a and u temporarily
# in order to drop any thing permanantly we have to use inplace=tru
df.drop('u',axis=1,inplace=True)

# %%
df
# Out:
#           p         q         r         s         t
# a -1.276265 -0.441164  1.088538  0.055988 -0.812554
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269
# d -1.273295  0.558726 -0.784153  1.434853  0.587968
# e  1.001514  0.213916  0.417707  0.180338 -0.784085

# %%
df.drop(['p','q'],axis=1)
# Out:
#           r         s         t
# a  1.088538  0.055988 -0.812554
# b -0.704728 -0.392833  1.024017
# c -0.859729 -0.272427 -0.595269
# d -0.784153  1.434853  0.587968
# e  0.417707  0.180338 -0.784085

# %%
# reset the previous indices i dont want a,b,c,d,e
df.reset_index(inplace=True)

# %%
df
# Out:
#           p         q         r         s         t
# a -1.276265 -0.441164  1.088538  0.055988 -0.812554
# b -0.207470  0.464722 -0.704728 -0.392833  1.024017
# c  1.046727  0.369640 -0.859729 -0.272427 -0.595269
# d -1.273295  0.558726 -0.784153  1.434853  0.587968
# e  1.001514  0.213916  0.417707  0.180338 -0.784085

# %%
df
# Out:
#   index         p         q         r         s         t
# 0     a -1.276265 -0.441164  1.088538  0.055988 -0.812554
# 1     b -0.207470  0.464722 -0.704728 -0.392833  1.024017
# 2     c  1.046727  0.369640 -0.859729 -0.272427 -0.595269
# 3     d -1.273295  0.558726 -0.784153  1.434853  0.587968
# 4     e  1.001514  0.213916  0.417707  0.180338 -0.784085

# %%
# Self Practice_Class1
import pandas as pd
import numpy as np

# %%
list1=[1,4,5,6,5,8]
# convert into lsit1 into an array

array=np.array(list1)

# %%
d
# Out:
# array([1, 4, 5, 6, 5, 8])

# %%
#Covert the above list into a pandas series
series1=pd.Series(list1)

# %%
series1
# Out:
# 0    1
# 1    4
# 2    5
# 3    6
# 4    5
# 5    8
# dtype: int64

# %%
series2=pd.Series(array)

# %%
series2
# Out:
# 0    1
# 1    4
# 2    5
# 3    6
# 4    5
# 5    8
# dtype: int64

# %%
# fetching elements 

series1[2:]
# Out:
# 2    5
# 3    6
# 4    5
# 5    8
# dtype: int64

# %%
# We can create our own indices and column

indices=['a','b','c','d','e','f']

pd.Series(data=list1,index=indices)
# Out:
# a    1
# b    4
# c    5
# d    6
# e    5
# f    8
# dtype: int64

# %%
pd.Series(list1,indices)
# Out:
# a    1
# b    4
# c    5
# d    6
# e    5
# f    8
# dtype: int64

# %%
#pd.concat([series1,series2])
pd.concat([series1,series2],axis=1)
# Out:
#    0  1
# 0  1  1
# 1  4  4
# 2  5  5
# 3  6  6
# 4  5  5
# 5  8  8

# %%
np.random.randn(5,5)
# Out:
# array([[-1.15516911, -0.81207428, -0.21406073, -1.05915522, -0.64296467],
#        [ 0.19479224,  0.14837356, -0.15594544,  0.20470456,  1.60214475],
#        [-0.62065945, -1.13351021,  0.08055656, -0.56387229,  0.314986  ],
#        [ 0.23067164,  0.88397758,  0.60950875, -1.09816597,  1.01144986],
#        [-0.26491787, -0.45591773,  1.5549164 ,  1.24198633, -0.0275327 ]])

# %%
# i want to convert array into DataFrame 

df=pd.DataFrame(np.random.randn(5,5))

# %%
df=pd.DataFrame(np.random.randn(5,5),index=['a','b','c','d','e'],columns=['p','q','r','s','t'])

# %%
df
# Out:
#           p         q         r         s         t
# a  0.233800  0.812989 -0.298136 -1.037413  0.278548
# b -0.158911 -1.579772 -0.205421 -0.822126  0.432848
# c  0.425167  1.392460 -0.141157  0.577772  1.104595
# d -0.569529 -0.453976  0.179962  0.028925 -0.940969
# e  1.063263 -0.402888  0.150140 -0.657442  2.091428

# %%
df["p"]
# Out:
# a    0.233800
# b   -0.158911
# c    0.425167
# d   -0.569529
# e    1.063263
# Name: p, dtype: float64

# %%
df.iloc[0]
# Out:
# p    0.233800
# q    0.812989
# r   -0.298136
# s   -1.037413
# t    0.278548
# Name: a, dtype: float64

# %%
df.iloc[0:]
# Out:
#           p         q         r         s         t
# a  0.233800  0.812989 -0.298136 -1.037413  0.278548
# b -0.158911 -1.579772 -0.205421 -0.822126  0.432848
# c  0.425167  1.392460 -0.141157  0.577772  1.104595
# d -0.569529 -0.453976  0.179962  0.028925 -0.940969
# e  1.063263 -0.402888  0.150140 -0.657442  2.091428

# %%
df.loc[['a']]
# Out:
#         p         q         r         s         t
# a  0.2338  0.812989 -0.298136 -1.037413  0.278548

# %%
df.loc[['a','b'],['p','q']]
# Out:
#           p         q
# a  0.233800  0.812989
# b -0.158911 -1.579772

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-9b6941c547db> in <module>()
# ----> 1 df.loc['p'],axis=1
#
# TypeError: cannot unpack non-iterable int object
