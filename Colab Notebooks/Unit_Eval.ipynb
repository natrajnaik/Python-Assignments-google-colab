# %%
import csv

# %%
with open("/content/sales.csv") as f:
  reader=csv.reader(f)
  rows=[]
  
  for row in reader:
    rows.append(row)

# %%
# rows
cols=next(iter(f))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-7100ae5fd9c6> in <module>()
#       1 # rows
# ----> 2 cols=next(iter(f))
#
# ValueError: I/O operation on closed file.

# %%
# rows
cols
# Out:
# 'Ship Mode,Segment,Country,City,State,Postal Code,Region,Category,Sub-Category,Sales,Quantity,Discount,Profit\n'

# %%
for i in rows:
  # print(i[4],sum(int(i[9])),sum(int(i[10])),sum(int(i[12])))
   print(i[9])
# Out:
# Streaming output truncated to the last 5000 lines.
# 20.32
# 52.064
# 48.784
# 13.092
# 109.592
# 56.7
# 79.99
# 69.5
# 191.6
# 10.56
# 47.79
# 714.3
# 2321.9
# 17.94
# 9.522
# 791.964
# 4.923
# 209.979
# 33.93
# 222.32
# 210.564
# 35.168
# 1502.376
# 10.11
# 772.47
# 20.46
# 347.58
# 72.64
# 772.47
# 39.92
# 33.48
# 461.97
# 137.62
# 302.67
# 239.976
# 8.34
# 8.57
# 119.616
# 212.94
# 26.49
# 687.4
# 653.55
# 33.9
# 239.96
# 199.836
# 716
# 221.06
# 67.71
# 129.92
# 467.46
# 61.4
# 720.76
# 5.184
# 14.7
# 8.134
# 79.984
# 18.54
# 24.4
# 195.64
# 398.4
# 7.056
# 1352.3976
# 26.4
# 41.88
# 99.846
# 699.98
# 584.82
# 43.98
# 377.97
# 123.96
# 391.98
# 383.976
# 1781.682
# 21.4
# 549.99
# 167.535
# 38.34
# 53.88
# 299.98
# 62.8
# 13.904
# 744.1
# 44.84
# 401.59
# 18.24
# 359.499
# 10.48
# 20.736
# 35.168
# 64.704
# 105.52
# 5.792
# 466.158
# 10.312
# 2.556
# 7.968
# 8.784
# 3.024
# 51.45
# 14.016
# 214.95
# 35.04
# 10.776
# 4.6
# 35.168
# 19.152
# 4.448
# 5.184
# 15.552
# 40.032
# ...
