# %%
import csv
with open("/content/drive/MyDrive/Colab Notebooks/births_usa.csv",'r') as csvfile:
  x=csv.reader(csvfile)
  for i in x:
    print(i[-1])
# Out:
# Streaming output truncated to the last 5000 lines.
# 12981
# 12728
# 12560
# 12335
# 8574
# 7602
# 11416
# 13037
# 12542
# 12596
# 12276
# 8795
# 8001
# 11635
# 13032
# 12477
# 12632
# 12296
# 8692
# 7479
# 11577
# 13124
# 12625
# 12630
# 12313
# 8803
# 7732
# 11680
# 13047
# 12936
# 13179
# 12722
# 8911
# 7529
# 7993
# 12013
# 13334
# 13051
# 12677
# 8920
# 7887
# 11500
# 12683
# 12804
# 12566
# 12451
# 8756
# 7674
# 11776
# 13218
# 12342
# 12655
# 12394
# 8780
# 7722
# 11756
# 12785
# 12704
# 12615
# 12299
# 8452
# 7639
# 11575
# 12939
# 12809
# 13059
# 12922
# 9247
# 8145
# 12390
# 13364
# 9608
# 12531
# 13151
# 9544
# 8249
# 12036
# 13614
# 13026
# 13188
# 12187
# 9269
# 8047
# 12383
# 13657
# 13241
# 13293
# 12950
# 9410
# 8116
# 12099
# 13532
# 12988
# 13022
# 12677
# 9102
# 7892
# 12150
# 13218
# 12960
# 13097
# 12859
# 9143
# 8062
# 12008
# 13488
# 13185
# 13339
# 13094
# 9275
# 8261
# 11682
# 13325
# 13332
# 13372
# 13102
# 9294
# 7945
# 12313
# 13590
# 13146
# 13158
# ...
